# %%
#import pandera as pa não funciona no windows 32
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=["ocorrencia_dia", "divulgacao_dia_publicacao"], dayfirst=True)
df.head(10)
#df.tail(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# ...

# %% [raw]
# df.dtypes
# df.ocorrencia_dia
# 0      2010-03-01
# 1      2010-03-01
# 2      2010-03-01
# 3      2010-04-01
# 4      2010-05-01
#           ...
# 6109   2021-08-15
# 6110   2021-08-16
# 6111   2021-08-17
# 6112   2021-08-18
# 6113   2021-08-18
# Name: ocorrencia_dia, Length: 6114, dtype: datetime64[ns]

# %% [raw]
# pip install pandera não funciona com windows 32 bits pacote muito bom para validacao de datas
#
# fazendo schemas com panderas
# schemas = pa.DataFrameSchema(
#        columns = {
#            "codigo":pa.Column(pa.Int, required=False),
#            "codigo_ocorrencia":pa.Column(pa.Int),
#            "ocorrencia_dia":pa.Column(pa.DateTime),
#            "divulgacao_dia_publicacao":pa.Column(pa.DateTime),
#            "ocorrencia_classificacao":pa.Column(pa.String),
#            "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
#            "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])?$), nullable=True)
#        }
# )
#
# schemas.validate(df)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao         datetime64[ns]
# ...
