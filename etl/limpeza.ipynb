# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=["ocorrencia_dia", "divulgacao_dia_publicacao"], dayfirst=True)
df.head(5)
#df.tail(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.loc[1, "ocorrencia_cidade"]
# Out:
# 'BELÉM'

# %%
df.loc[1:2]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN             BELÉM            PA
# 2                 NaN                  NaN    RIO DE JANEIRO            RJ
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 1          FINALIZADA                         NaN
# ...

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# ...

# %%
df.loc[:,"ocorrencia_cidade"]
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.ocorrencia_cidade.is_unique
# Out:
# False

# %% [raw]
# df.set_index("ocorrencia_cidade", inplace=True)
# df.reset_index("ocorrencia_cidade", inplace=True)

# %%
df.loc[0, "ocorrencia_latitude"] = ""

# %%
df.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                                      ***    RIO DE JANEIRO            RJ
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaT
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
#
# [1 rows x 22 columns]

# %%
df.loc[df.ocorrencia_uf == "SP", ["ocorrencia_classificacao"]] = "GRAVE"

# %%
df.loc[df.ocorrencia_uf == "SP"]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 11                40069               40069               40069
# 16                39809               39809               39809
# 18                39828               39828               39828
# 26                39847               39847               39847
# 27                39768               39768               39768
# ...                 ...                 ...                 ...
# 6084              80234               80234               80234
# 6085              80208               80208               80208
# 6104              80238               80238               80238
# 6108              80244               80244               80244
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 11                 40069               40069                    GRAVE
# ...

# %% [raw]
# ***	investigacao_aeronave_liberada, divulgacao_relatorio_numero

# %%
df.loc[df.divulgacao_relatorio_numero == "***", ["divulgacao_relatorio_numero"]] = pd.NA

# %%
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# ...

# %%
df.replace(['NaN', "***"], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2285
# ocorrencia_longitude              2287
# ocorrencia_cidade                    0
# ocorrencia_uf                        2
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2399
# investigacao_status                341
# divulgacao_relatorio_numero       3913
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4537
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [raw]
#     df.fillna(0) altera todos os dados na visualização de null para 0, se quiser alterar no dataframe de fato não esquecer do inplace=True
#
#     df.fillna(value={"total_recomendacoes":10}) altera os dados null somente da coluna total_recomendacoes no caso paea 10

# %%
df["total_recomendacoes.vkp"] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                                     <NA>      RIO DE JANEIRO            RJ
# ...

# %%
df.drop(["total_recomendacoes.vkp"], axis=1) #axis=1 refere-se a coluna e axis=0 refere-se a linha
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %% [raw]
# df.dropna() remove todas as linhas que tenha algum dado nulo
# df.dropna(subset=["total_recomendacoes"])
# df.drop_duplicates() - elimina linhas duplicadas
